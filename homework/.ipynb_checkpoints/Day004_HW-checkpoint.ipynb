# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11202379963","type":"PushEvent","actor":{"id":43469473,"login":"abdulmannans","display_login":"abdulmannans","gravatar_id":"","url":"https://api.github.com/users/abdulmannans","avatar_url":"https://avatars.githubusercontent.com/u/43469473?"},"repo":{"id":228392456,"name":"abdulmannans/Java","url":"https://api.github.com/repos/abdulmannans/Java"},"payload":{"push_id":4460340589,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"26b4bd36a1b05a65a45841da38de30fa7e2dbacb","before":"8df14ff91dcdb963bf52c2896c8a5323abfd4aaa","commits":[{"sha":"26b4bd36a1b05a65a45841da38de30fa7e2dbacb","author":{"email":"43469473+abdulmannans@users.noreply.github.com","name":"SIDDIQUEI ABDUL MANNAN"},"message":"Delete pom.xml","distinct":true,"url":"https://api.github.com/repos/abdulmannans/Java/commits/26b4bd36a1b05a65a45841da38de30fa7e2dbacb"}]},"public":true,"created_at":"2020-01-04T12:03:33Z"},{"id":"11202379970","type":"WatchEvent","actor":{"id":592313,"login":"sebst","display_login":"sebst","gravatar_id":"","url":"https://api.github.com/users/sebst","avatar_url":"https://avatars.githubusercontent.com/u/592313?"},"repo":{"id":209153501,"name":"smallwat3r/shhh","url":"https://api.github.com/repos/smallwat3r/shhh"},"payload":{"action":"started"},"public":true,"created_at":"2020-01-04T12:03:33Z"},{"id":"11202379958","type":"PushEvent","actor":{"id":5256300,"login":"Cu3PO42","display_login":"Cu3PO42","gravatar_id":"","url":"https://api.github.com/users/Cu3PO42","avatar_url":"https://avatars.githubusercontent.com/u/5256300?"},"repo":{"id":116066128,"name":"Cu3PO42/SVEx-Crawler","url":"https://api.github.com/repos/Cu3PO42/SVEx-Crawler"},"payload":{"push_id":4460340587,"size":1,"distinct_size":1,"ref":"refs/heads/gh-pages","head":"52f89984360f28293ac525425577c3ec2a7cf2c9","before":"eb786146f6e43363b9bb52f464362438084872de","commits":[{"sha":"52f89984360f28293ac525425577c3ec2a7cf2c9","author":{"email":"cu3po42+ci@gmail.com","name":"Cu3PO42 (CI)"},"message":"Deploy to GitHub pages (1/4/2020 12:03 PM)","distinct":true,"url":"https://api.github.com/repos/Cu3PO42/SVEx-Crawler/commits/52f89984360f28293ac525425577c3ec2a7cf2c9"}]},"public":true,"created_at":"2020-01-04T12:03:33Z"},{"id":"11202379949","type":"PushEvent","actor":{"id":16307144,"login":"5john","display_login":"5john","gravatar_id":"","url":"https://api.github.com/users/5john","avatar_url":"https://avatars.githubusercontent.com/u/16307144?"},"repo":{"id":211601139,"name":"5john/5john","url":"https://api.github.com/repos/5john/5john"},"payload":{"push_id":4460340580,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"0fe1699ad593629c16c28856de9e7bc77ef5513d","before":"c881dd61c2ec72dd942bbc4d9eb2096d7949edab","commits":[{"sha":"0fe1699ad593629c16c28856de9e7bc77ef5513d","author":{"email":"397633614@qq.com","name":"5john"},"message":"2020/01/04 12:03:30    4_tkkktg@linshiyouxiang.net","distinct":true,"url":"https://api.github.com/repos/5john/5john/commits/0fe1699ad593629c16c28856de9e7bc77ef5513d"}]},"public":true,"created_at":"2020-01-04T12:03:33Z"},{"id":"11202379951","type":"PushEvent","actor":{"id":8517910,"login":"LombiqBot","display_login":"LombiqBot","gravatar_id":"","url":"https://api.github.com/users/LombiqBot","avatar_url":"https://avatars.githubusercontent.com/u/8517910?"},"repo":{"id":107553486,"name":"Lombiq/Orchard-Ambassadors-Theme","url":"https://api.github.com/repos/Lombiq/Orchard-Ambassadors-Theme"},"payload":{"push_id":4460340586,"size":0,"distinct_size":0,"ref":"refs/heads/issue/BTLR-63","head":"a401ba334eb52d8c0e0d83a8a3d409dea8c8f9b1","before":"a401ba334eb52d8c0e0d83a8a3d409dea8c8f9b1","commits":[]},"public":true,"created_at":"2020-01-04T12:03:33Z","org":{"id":8158177,"login":"Lombiq","gravatar_id":"","url":"https://api.github.com/orgs/Lombiq","avatar_url":"https://avatars.githubusercontent.com/u/8158177?"}},{"id":"11202379945","type":"PushEvent","actor":{"id":54087641,"login":"programacion-desde-cero","display_login":"programacion-desde-cero","gravata ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11202379963',
#   'type': 'PushEvent',
#   'actor': {'id': 43469473,
#    'login': 'abdulmannans',
#    'display_login': 'abdulmannans',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/abdulmannans',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43469473?'},
#   'repo': {'id': 228392456,
#    'name': 'abdulmannans/Java',
#    'url': 'https://api.github.com/repos/abdulmannans/Java'},
#   'payload': {'push_id': 4460340589,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '26b4bd36a1b05a65a45841da38de30fa7e2dbacb',
#    'before': '8df14ff91dcdb963bf52c2896c8a5323abfd4aaa',
#    'commits': [{'sha': '26b4bd36a1b05a65a45841da38de30fa7e2dbacb',
#      'author': {'email': '43469473+abdulmannans@users.noreply.github.com',
#       'name': 'SIDDIQUEI ABDUL MANNAN'},
#      'message': 'Delete pom.xml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/abdulmannans/Java/commits/26b4bd36a1b05a65a45841da38de30fa7e2dbacb'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:33Z'},
#  {'id': '11202379970',
#   'type': 'WatchEvent',
#   'actor': {'id': 592313,
#    'login': 'sebst',
#    'display_login': 'sebst',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sebst',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/592313?'},
#   'repo': {'id': 209153501,
#    'name': 'smallwat3r/shhh',
#    'url': 'https://api.github.com/repos/smallwat3r/shhh'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-01-04T12:03:33Z'},
#  {'id': '11202379958',
#   'type': 'PushEvent',
#   'actor': {'id': 5256300,
#    'login': 'Cu3PO42',
#    'display_login': 'Cu3PO42',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Cu3PO42',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5256300?'},
#   'repo': {'id': 116066128,
#    'name': 'Cu3PO42/SVEx-Crawler',
#    'url': 'https://api.github.com/repos/Cu3PO42/SVEx-Crawler'},
#   'payload': {'push_id': 4460340587,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '52f89984360f28293ac525425577c3ec2a7cf2c9',
#    'before': 'eb786146f6e43363b9bb52f464362438084872de',
#    'commits': [{'sha': '52f89984360f28293ac525425577c3ec2a7cf2c9',
#      'author': {'email': 'cu3po42+ci@gmail.com', 'name': 'Cu3PO42 (CI)'},
#      'message': 'Deploy to GitHub pages (1/4/2020 12:03 PM)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Cu3PO42/SVEx-Crawler/commits/52f89984360f28293ac525425577c3ec2a7cf2c9'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:33Z'},
#  {'id': '11202379949',
#   'type': 'PushEvent',
#   'actor': {'id': 16307144,
#    'login': '5john',
#    'display_login': '5john',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/5john',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16307144?'},
#   'repo': {'id': 211601139,
#    'name': '5john/5john',
#    'url': 'https://api.github.com/repos/5john/5john'},
#   'payload': {'push_id': 4460340580,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0fe1699ad593629c16c28856de9e7bc77ef5513d',
#    'before': 'c881dd61c2ec72dd942bbc4d9eb2096d7949edab',
#    'commits': [{'sha': '0fe1699ad593629c16c28856de9e7bc77ef5513d',
#      'author': {'email': '397633614@qq.com', 'name': '5john'},
#      'message': '2020/01/04 12:03:30    4_tkkktg@linshiyouxiang.net',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/5john/5john/commits/0fe1699ad593629c16c28856de9e7bc77ef5513d'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:33Z'},
#  {'id': '11202379951',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 107553486,
#    'name': 'Lombiq/Orchard-Ambassadors-Theme',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard-Ambassadors-Theme'},
#   'payload': {'push_id': 4460340586,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/issue/BTLR-63',
#    'head': 'a401ba334eb52d8c0e0d83a8a3d409dea8c8f9b1',
#    'before': 'a401ba334eb52d8c0e0d83a8a3d409dea8c8f9b1',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-01-04T12:03:33Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11202379945',
#   'type': 'PushEvent',
#   'actor': {'id': 54087641,
#    'login': 'programacion-desde-cero',
#    'display_login': 'programacion-desde-cero',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/programacion-desde-cero',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54087641?'},
#   'repo': {'id': 205722026,
#    'name': 'programacion-desde-cero/material-de-estudio',
#    'url': 'https://api.github.com/repos/programacion-desde-cero/material-de-estudio'},
#   'payload': {'push_id': 4460340578,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '4f3a2080c3ff04f0fc899c50f93e8c9eff9e2e77',
#    'before': 'e7faf1e4b83549c90124d1e17b16f85255dea2f5',
#    'commits': [{'sha': '4f3a2080c3ff04f0fc899c50f93e8c9eff9e2e77',
#      'author': {'email': '54087641+programacion-desde-cero@users.noreply.github.com',
#       'name': 'Programación Desde Cero'},
#      'message': 'Delete referencia_UML.pdf',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/programacion-desde-cero/material-de-estudio/commits/4f3a2080c3ff04f0fc899c50f93e8c9eff9e2e77'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:33Z'},
#  {'id': '11202379942',
#   'type': 'PushEvent',
#   'actor': {'id': 58382954,
#    'login': 'Lee-Si-Hwan',
#    'display_login': 'Lee-Si-Hwan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Lee-Si-Hwan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58382954?'},
#   'repo': {'id': 230758253,
#    'name': 'Lee-Si-Hwan/my-project',
#    'url': 'https://api.github.com/repos/Lee-Si-Hwan/my-project'},
#   'payload': {'push_id': 4460340577,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '12c71f1e911138994c29214525ac3b7640bd8031',
#    'before': '9253dfce0369d5003210d708abcf0ca3810af4ad',
#    'commits': [{'sha': '12c71f1e911138994c29214525ac3b7640bd8031',
#      'author': {'email': '58382954+Lee-Si-Hwan@users.noreply.github.com',
#       'name': 'Lee-Si-Hwan'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Lee-Si-Hwan/my-project/commits/12c71f1e911138994c29214525ac3b7640bd8031'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:33Z'},
#  {'id': '11202379941',
#   'type': 'CreateEvent',
#   'actor': {'id': 45848134,
#    'login': 'klavdijav',
#    'display_login': 'klavdijav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/klavdijav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45848134?'},
#   'repo': {'id': 231755516,
#    'name': 'RSO-lb-kv/image-upload-ms',
#    'url': 'https://api.github.com/repos/RSO-lb-kv/image-upload-ms'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-04T12:03:33Z',
#   'org': {'id': 56347941,
#    'login': 'RSO-lb-kv',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/RSO-lb-kv',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56347941?'}},
#  {'id': '11202379943',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 67428,
#    'login': 'jelly',
#    'display_login': 'jelly',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jelly',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67428?'},
#   'repo': {'id': 177214812,
#    'name': 'archlinux/contrib',
#    'url': 'https://api.github.com/repos/archlinux/contrib'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/archlinux/contrib/issues/13',
#     'repository_url': 'https://api.github.com/repos/archlinux/contrib',
#     'labels_url': 'https://api.github.com/repos/archlinux/contrib/issues/13/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/archlinux/contrib/issues/13/comments',
#     'events_url': 'https://api.github.com/repos/archlinux/contrib/issues/13/events',
#     'html_url': 'https://github.com/archlinux/contrib/pull/13',
#     'id': 511525217,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzMxNzA2NzEx',
#     'number': 13,
#     'title': 'Add tool to generate dbscripts commands for todolists',
#     'user': {'login': 'jelly',
#      'id': 67428,
#      'node_id': 'MDQ6VXNlcjY3NDI4',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/67428?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jelly',
#      'html_url': 'https://github.com/jelly',
#      'followers_url': 'https://api.github.com/users/jelly/followers',
#      'following_url': 'https://api.github.com/users/jelly/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jelly/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jelly/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jelly/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jelly/orgs',
#      'repos_url': 'https://api.github.com/users/jelly/repos',
#      'events_url': 'https://api.github.com/users/jelly/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jelly/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 5,
#     'created_at': '2019-10-23T19:27:32Z',
#     'updated_at': '2020-01-04T12:03:33Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'pull_request': {'url': 'https://api.github.com/repos/archlinux/contrib/pulls/13',
#      'html_url': 'https://github.com/archlinux/contrib/pull/13',
#      'diff_url': 'https://github.com/archlinux/contrib/pull/13.diff',
#      'patch_url': 'https://github.com/archlinux/contrib/pull/13.patch'},
#     'body': 'staging2testing outputs the to be executed commands for a todolist which\r\ncan be moved to [testing].\r\n\r\nSigned-off-by: Jelle van der Waa <jelle@archlinux.org>'},
#    'comment': {'url': 'https://api.github.com/repos/archlinux/contrib/issues/comments/570779950',
#     'html_url': 'https://github.com/archlinux/contrib/pull/13#issuecomment-570779950',
#     'issue_url': 'https://api.github.com/repos/archlinux/contrib/issues/13',
#     'id': 570779950,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU3MDc3OTk1MA==',
#     'user': {'login': 'jelly',
#      'id': 67428,
#      'node_id': 'MDQ6VXNlcjY3NDI4',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/67428?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jelly',
#      'html_url': 'https://github.com/jelly',
#      'followers_url': 'https://api.github.com/users/jelly/followers',
#      'following_url': 'https://api.github.com/users/jelly/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jelly/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jelly/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jelly/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jelly/orgs',
#      'repos_url': 'https://api.github.com/users/jelly/repos',
#      'events_url': 'https://api.github.com/users/jelly/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jelly/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-01-04T12:03:33Z',
#     'updated_at': '2020-01-04T12:03:33Z',
#     'author_association': 'MEMBER',
#     'body': 'So just add an extra argument ideally, target? testing or stable!'}},
#   'public': True,
#   'created_at': '2020-01-04T12:03:33Z',
#   'org': {'id': 4673648,
#    'login': 'archlinux',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/archlinux',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4673648?'}},
#  {'id': '11202379940',
#   'type': 'PushEvent',
#   'actor': {'id': 58188677,
#    'login': 'hardenedbsd-services',
#    'display_login': 'hardenedbsd-services',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hardenedbsd-services',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58188677?'},
#   'repo': {'id': 225229164,
#    'name': 'HardenedBSD/logs',
#    'url': 'https://api.github.com/repos/HardenedBSD/logs'},
#   'payload': {'push_id': 4460340571,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a200332e7eef252fb59550eb7d37a2c2dff77238',
#    'before': 'a8ac34f415efe95df2dfb21c8ba3cf6ea1605926',
#    'commits': [{'sha': 'a200332e7eef252fb59550eb7d37a2c2dff77238',
#      'author': {'email': 'dev@hardenedbsd.org',
#       'name': 'HardenedBSD Sync Service'},
#      'message': 'SYNC: [OK] freebsd:current:master-20200104070000.log',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/HardenedBSD/logs/commits/a200332e7eef252fb59550eb7d37a2c2dff77238'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:33Z',
#   'org': {'id': 7223580,
#    'login': 'HardenedBSD',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/HardenedBSD',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7223580?'}},
#  {'id': '11202379935',
#   'type': 'PushEvent',
#   'actor': {'id': 29509761,
#    'login': 'AKANK16',
#    'display_login': 'AKANK16',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AKANK16',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29509761?'},
#   'repo': {'id': 229870472,
#    'name': 'AKANK16/Deloitte-Assessments',
#    'url': 'https://api.github.com/repos/AKANK16/Deloitte-Assessments'},
#   'payload': {'push_id': 4460340570,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c5fc95e2e74dc8d895f78e4ccc72527a0896f509',
#    'before': '5c3145c8d4ef704c00433da15266cbfe5f147e75',
#    'commits': [{'sha': 'c5fc95e2e74dc8d895f78e4ccc72527a0896f509',
#      'author': {'email': 'akankshak999@gmail.com', 'name': 'AKANK16'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AKANK16/Deloitte-Assessments/commits/c5fc95e2e74dc8d895f78e4ccc72527a0896f509'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:33Z'},
#  {'id': '11202379938',
#   'type': 'PushEvent',
#   'actor': {'id': 58139068,
#    'login': 'toddmnortonCO',
#    'display_login': 'toddmnortonCO',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/toddmnortonCO',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58139068?'},
#   'repo': {'id': 231755622,
#    'name': 'toddmnortonCO/python-dictionaries-lab-ds-apply-000',
#    'url': 'https://api.github.com/repos/toddmnortonCO/python-dictionaries-lab-ds-apply-000'},
#   'payload': {'push_id': 4460340575,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': 'c7b4b7cc3e4844327e96c9caf3f8e71297b7c1ef',
#    'before': '91dc33b27fe3446130c41a8d6948867672870f0b',
#    'commits': [{'sha': 'c7b4b7cc3e4844327e96c9caf3f8e71297b7c1ef',
#      'author': {'email': 'toddmnorton@live.com',
#       'name': 'inherited-snippet-0885'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/toddmnortonCO/python-dictionaries-lab-ds-apply-000/commits/c7b4b7cc3e4844327e96c9caf3f8e71297b7c1ef'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:33Z'},
#  {'id': '11202379936',
#   'type': 'ForkEvent',
#   'actor': {'id': 6001560,
#    'login': 'NeatWolf',
#    'display_login': 'NeatWolf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NeatWolf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6001560?'},
#   'repo': {'id': 46333812,
#    'name': 'DavidArayan/ezy-slice',
#    'url': 'https://api.github.com/repos/DavidArayan/ezy-slice'},
#   'payload': {'forkee': {'id': 231756112,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMzE3NTYxMTI=',
#     'name': 'ezy-slice',
#     'full_name': 'NeatWolf/ezy-slice',
#     'private': False,
#     'owner': {'login': 'NeatWolf',
#      'id': 6001560,
#      'node_id': 'MDQ6VXNlcjYwMDE1NjA=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/6001560?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/NeatWolf',
#      'html_url': 'https://github.com/NeatWolf',
#      'followers_url': 'https://api.github.com/users/NeatWolf/followers',
#      'following_url': 'https://api.github.com/users/NeatWolf/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/NeatWolf/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/NeatWolf/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/NeatWolf/subscriptions',
#      'organizations_url': 'https://api.github.com/users/NeatWolf/orgs',
#      'repos_url': 'https://api.github.com/users/NeatWolf/repos',
#      'events_url': 'https://api.github.com/users/NeatWolf/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/NeatWolf/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/NeatWolf/ezy-slice',
#     'description': 'An open source mesh slicer framework for Unity3D Game Engine. Written in C#.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/NeatWolf/ezy-slice',
#     'forks_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/forks',
#     'keys_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/teams',
#     'hooks_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/hooks',
#     'issue_events_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/events',
#     'assignees_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/tags',
#     'blobs_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/languages',
#     'stargazers_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/stargazers',
#     'contributors_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/contributors',
#     'subscribers_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/subscribers',
#     'subscription_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/subscription',
#     'commits_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/merges',
#     'archive_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/downloads',
#     'issues_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/NeatWolf/ezy-slice/deployments',
#     'created_at': '2020-01-04T12:03:32Z',
#     'updated_at': '2020-01-04T12:03:29Z',
#     'pushed_at': '2019-12-05T23:25:52Z',
#     'git_url': 'git://github.com/NeatWolf/ezy-slice.git',
#     'ssh_url': 'git@github.com:NeatWolf/ezy-slice.git',
#     'clone_url': 'https://github.com/NeatWolf/ezy-slice.git',
#     'svn_url': 'https://github.com/NeatWolf/ezy-slice',
#     'homepage': None,
#     'size': 425,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-01-04T12:03:33Z'},
#  {'id': '11202379930',
#   'type': 'PushEvent',
#   'actor': {'id': 13459548,
#    'login': 'Daniel085',
#    'display_login': 'Daniel085',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Daniel085',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13459548?'},
#   'repo': {'id': 105188764,
#    'name': 'Daniel085/V3API',
#    'url': 'https://api.github.com/repos/Daniel085/V3API'},
#   'payload': {'push_id': 4460340560,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6831ace9ee818156f7fc2a56482b748dd36e2b56',
#    'before': '40221e1ec41d8415dfd2f932b8929614d1e7fc96',
#    'commits': [{'sha': '6831ace9ee818156f7fc2a56482b748dd36e2b56',
#      'author': {'email': 'daniel@voicebase.com', 'name': "Daniel O'Rorke"},
#      'message': 'Postman updated VoiceBase v3 API',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Daniel085/V3API/commits/6831ace9ee818156f7fc2a56482b748dd36e2b56'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z'},
#  {'id': '11202379933',
#   'type': 'PushEvent',
#   'actor': {'id': 59293082,
#    'login': 'lihkg-boy',
#    'display_login': 'lihkg-boy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lihkg-boy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59293082?'},
#   'repo': {'id': 230501783,
#    'name': 'lihkg-backup/thread',
#    'url': 'https://api.github.com/repos/lihkg-backup/thread'},
#   'payload': {'push_id': 4460340565,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fa75b567c94b611f57a6630d935dc0623182e7d4',
#    'before': 'afc4cef755099846b06c92ce686b2b30697d1f24',
#    'commits': [{'sha': 'fa75b567c94b611f57a6630d935dc0623182e7d4',
#      'author': {'email': 'lihkg@github.com', 'name': 'lihkg'},
#      'message': 'update 1805473.json 2020-01-04T12:03:30.042Z',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lihkg-backup/thread/commits/fa75b567c94b611f57a6630d935dc0623182e7d4'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z',
#   'org': {'id': 58919150,
#    'login': 'lihkg-backup',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/lihkg-backup',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58919150?'}},
#  {'id': '11202379931',
#   'type': 'PushEvent',
#   'actor': {'id': 4464333,
#    'login': 'lindyhopchris',
#    'display_login': 'lindyhopchris',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lindyhopchris',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4464333?'},
#   'repo': {'id': 197137338,
#    'name': 'cloudcreativity/laravel-stripe',
#    'url': 'https://api.github.com/repos/cloudcreativity/laravel-stripe'},
#   'payload': {'push_id': 4460340567,
#    'size': 4,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': '0da9eccf26858494364300a07c7670b3885f5607',
#    'before': '77089810bc32e3c90543df31cb77a1d67e37aacf',
#    'commits': [{'sha': 'dfd3d5a60f2c2f4552b3e2e810638aa8bc01b968',
#      'author': {'email': 'contact@gammie.co.uk', 'name': 'Christopher Gammie'},
#      'message': '[Build] Fix facade alias\n\nCloses #3',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/cloudcreativity/laravel-stripe/commits/dfd3d5a60f2c2f4552b3e2e810638aa8bc01b968'},
#     {'sha': '143eca64ca8e54cbef3eb88899a0e1bbf7cf146d',
#      'author': {'email': 'contact@gammie.co.uk', 'name': 'Christopher Gammie'},
#      'message': '[Docs] Update changelog and bump version',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/cloudcreativity/laravel-stripe/commits/143eca64ca8e54cbef3eb88899a0e1bbf7cf146d'},
#     {'sha': 'ba805d174183dc306896c1bdbf756182388c5b25',
#      'author': {'email': 'contact@gammie.co.uk', 'name': 'Christopher Gammie'},
#      'message': "Merge branch 'hotfix/0.1.1'",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/cloudcreativity/laravel-stripe/commits/ba805d174183dc306896c1bdbf756182388c5b25'},
#     {'sha': '0da9eccf26858494364300a07c7670b3885f5607',
#      'author': {'email': 'contact@gammie.co.uk', 'name': 'Christopher Gammie'},
#      'message': "Merge tag 'v0.1.1' into develop\n\nFix facade alias.",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cloudcreativity/laravel-stripe/commits/0da9eccf26858494364300a07c7670b3885f5607'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z',
#   'org': {'id': 12550113,
#    'login': 'cloudcreativity',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cloudcreativity',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12550113?'}},
#  {'id': '11202379932',
#   'type': 'CreateEvent',
#   'actor': {'id': 28509305,
#    'login': 'jackholf',
#    'display_login': 'jackholf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jackholf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28509305?'},
#   'repo': {'id': 231756111,
#    'name': 'jackholf/-',
#    'url': 'https://api.github.com/repos/jackholf/-'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'http://hackinglab.cn/ShowQues.php?type=scripts',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z'},
#  {'id': '11202379929',
#   'type': 'PushEvent',
#   'actor': {'id': 16861681,
#    'login': 'yuangezhizao',
#    'display_login': 'yuangezhizao',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yuangezhizao',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16861681?'},
#   'repo': {'id': 164144796,
#    'name': 'yuangezhizao/bilibili_splash_fetch_data',
#    'url': 'https://api.github.com/repos/yuangezhizao/bilibili_splash_fetch_data'},
#   'payload': {'push_id': 4460340566,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b8c20e0821c7f9001ffd537455c82677ce7be7d3',
#    'before': '44d43ed1a9b3b3bc858d304bb50a7f643a010ca5',
#    'commits': [{'sha': 'b8c20e0821c7f9001ffd537455c82677ce7be7d3',
#      'author': {'email': 'yuangezhizao@gmail.com',
#       'name': 'yuangezhizao-serveraccount'},
#      'message': 'CentOS Server Cron Jobs at 2020-01-04 20:02:01',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/yuangezhizao/bilibili_splash_fetch_data/commits/b8c20e0821c7f9001ffd537455c82677ce7be7d3'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z'},
#  {'id': '11202379926',
#   'type': 'CreateEvent',
#   'actor': {'id': 1049634,
#    'login': 'RSATom',
#    'display_login': 'RSATom',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RSATom',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1049634?'},
#   'repo': {'id': 199468276,
#    'name': 'WebRTSP/Native',
#    'url': 'https://api.github.com/repos/WebRTSP/Native'},
#   'payload': {'ref': 'webrtsp-proxy-client-snap',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': '[WIP] Native WebRTSP client and server based on GStreamer',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z',
#   'org': {'id': 58672918,
#    'login': 'WebRTSP',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/WebRTSP',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58672918?'}},
#  {'id': '11202379925',
#   'type': 'PushEvent',
#   'actor': {'id': 5770480,
#    'login': 'ykws',
#    'display_login': 'ykws',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ykws',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5770480?'},
#   'repo': {'id': 231235967,
#    'name': 'ykws/hello-prolog',
#    'url': 'https://api.github.com/repos/ykws/hello-prolog'},
#   'payload': {'push_id': 4460340564,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '84f2f9dd95ebb1a6fbc76bce864de7f42cb9750e',
#    'before': '5f0f03717b95ff6fa5b420b08b2a2dafe2961abb',
#    'commits': [{'sha': '84f2f9dd95ebb1a6fbc76bce864de7f42cb9750e',
#      'author': {'email': 'ykawashi7@gmail.com', 'name': 'KAWASHIMA Yoshiyuki'},
#      'message': 'Add map to Examples',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ykws/hello-prolog/commits/84f2f9dd95ebb1a6fbc76bce864de7f42cb9750e'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z'},
#  {'id': '11202379923',
#   'type': 'WatchEvent',
#   'actor': {'id': 16574957,
#    'login': 'fodorad',
#    'display_login': 'fodorad',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fodorad',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16574957?'},
#   'repo': {'id': 99206780,
#    'name': 'otenim/Xception-with-Your-Own-Dataset',
#    'url': 'https://api.github.com/repos/otenim/Xception-with-Your-Own-Dataset'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z'},
#  {'id': '11202379920',
#   'type': 'PushEvent',
#   'actor': {'id': 29739800,
#    'login': 'robertsweeneyblanco',
#    'display_login': 'robertsweeneyblanco',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/robertsweeneyblanco',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29739800?'},
#   'repo': {'id': 231748704,
#    'name': 'robertsweeneyblanco/Programming_for_Mathematical_Applications',
#    'url': 'https://api.github.com/repos/robertsweeneyblanco/Programming_for_Mathematical_Applications'},
#   'payload': {'push_id': 4460340561,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2036dafc54f22dc56c87519ce883da021a10be56',
#    'before': 'eaff1d648a37cd40d423e8fe75a483ffcc77a8f2',
#    'commits': [{'sha': '2036dafc54f22dc56c87519ce883da021a10be56',
#      'author': {'email': 'robertsweeneyblanco@gmail.com',
#       'name': 'Robert Sweeney'},
#      'message': 'trying to fix config',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/robertsweeneyblanco/Programming_for_Mathematical_Applications/commits/2036dafc54f22dc56c87519ce883da021a10be56'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z'},
#  {'id': '11202379921',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 231754057,
#    'name': '1357280829/larabbs',
#    'url': 'https://api.github.com/repos/1357280829/larabbs'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/1357280829/larabbs/issues/2',
#     'repository_url': 'https://api.github.com/repos/1357280829/larabbs',
#     'labels_url': 'https://api.github.com/repos/1357280829/larabbs/issues/2/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/1357280829/larabbs/issues/2/comments',
#     'events_url': 'https://api.github.com/repos/1357280829/larabbs/issues/2/events',
#     'html_url': 'https://github.com/1357280829/larabbs/pull/2',
#     'id': 545276333,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU5MjA3ODI3',
#     'number': 2,
#     'title': 'Bump symfony/http-foundation from 4.3.4 to 4.4.2',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 1768014036,
#       'node_id': 'MDU6TGFiZWwxNzY4MDE0MDM2',
#       'url': 'https://api.github.com/repos/1357280829/larabbs/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 1768014053,
#       'node_id': 'MDU6TGFiZWwxNzY4MDE0MDUz',
#       'url': 'https://api.github.com/repos/1357280829/larabbs/labels/php',
#       'name': 'php',
#       'color': '45229e',
#       'default': False,
#       'description': 'Pull requests that update Php code'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-01-04T11:54:25Z',
#     'updated_at': '2020-01-04T12:03:32Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'pull_request': {'url': 'https://api.github.com/repos/1357280829/larabbs/pulls/2',
#      'html_url': 'https://github.com/1357280829/larabbs/pull/2',
#      'diff_url': 'https://github.com/1357280829/larabbs/pull/2.diff',
#      'patch_url': 'https://github.com/1357280829/larabbs/pull/2.patch'},
#     'body': '[//]: # (dependabot-start)\n⚠️  **Dependabot is rebasing this PR** ⚠️ \n\nIf you make any changes to it yourself then they will take precedence over the rebase.\n\n---\n\n[//]: # (dependabot-end)\n\nBumps [symfony/http-foundation](https://github.com/symfony/http-foundation) from 4.3.4 to 4.4.2.\n<details>\n<summary>Changelog</summary>\n\n*Sourced from [symfony/http-foundation\'s changelog](https://github.com/symfony/http-foundation/blob/master/CHANGELOG.md).*\n\n> CHANGELOG\n> =========\n> \n> 5.1.0\n> -----\n> \n>  * Deprecate `Response::create()`, `JsonResponse::create()`,\n>    `RedirectResponse::create()`, and `StreamedResponse::create()` methods (use\n>    `__construct()` instead)\n> \n> 5.0.0\n> -----\n> \n>  * made `Cookie` auto-secure and lax by default\n>  * removed classes in the `MimeType` namespace, use the Symfony Mime component instead\n>  * removed method `UploadedFile::getClientSize()` and the related constructor argument\n>  * made `Request::getSession()` throw if the session has not been set before\n>  * removed `Response::HTTP_RESERVED_FOR_WEBDAV_ADVANCED_COLLECTIONS_EXPIRED_PROPOSAL`\n>  * passing a null url when instantiating a `RedirectResponse` is not allowed\n> \n> 4.4.0\n> -----\n> \n>  * passing arguments to `Request::isMethodSafe()` is deprecated.\n>  * `ApacheRequest` is deprecated, use the `Request` class instead.\n>  * passing a third argument to `HeaderBag::get()` is deprecated, use method `all()` instead\n>  * [BC BREAK] `PdoSessionHandler` with MySQL changed the type of the lifetime column,\n>    make sure to run `ALTER TABLE sessions MODIFY sess_lifetime INTEGER UNSIGNED NOT NULL` to\n>    update your database.\n>  * `PdoSessionHandler` now precalculates the expiry timestamp in the lifetime column,\n>     make sure to run `CREATE INDEX EXPIRY ON sessions (sess_lifetime)` to update your database\n>     to speed up garbage collection of expired sessions.\n>  * added `SessionHandlerFactory` to create session handlers with a DSN\n>  * added `IpUtils::anonymize()` to help with GDPR compliance.\n> \n> 4.3.0\n> -----\n> \n>  * added PHPUnit constraints: `RequestAttributeValueSame`, `ResponseCookieValueSame`, `ResponseHasCookie`,\n>    `ResponseHasHeader`, `ResponseHeaderSame`, `ResponseIsRedirected`, `ResponseIsSuccessful`, and `ResponseStatusCodeSame`\n>  * deprecated `MimeTypeGuesserInterface` and `ExtensionGuesserInterface` in favor of `Symfony\\Component\\Mime\\MimeTypesInterface`.\n>  * deprecated `MimeType` and `MimeTypeExtensionGuesser` in favor of `Symfony\\Component\\Mime\\MimeTypes`.\n>  * deprecated `FileBinaryMimeTypeGuesser` in favor of `Symfony\\Component\\Mime\\FileBinaryMimeTypeGuesser`.\n>  * deprecated `FileinfoMimeTypeGuesser` in favor of `Symfony\\Component\\Mime\\FileinfoMimeTypeGuesser`.\n>  * added `UrlHelper` that allows to get an absolute URL and a relative path for a given path\n> \n> 4.2.0\n> -----\n> \n>  * the default value of the "$secure" and "$samesite" arguments of Cookie\'s constructor\n></tr></table> ... (truncated)\n</details>\n<details>\n<summary>Commits</summary>\n\n- [`fcae1cf`](https://github.com/symfony/http-foundation/commit/fcae1cff5b57b2a9c3aabefeb1527678705ddb62) Merge branch \'4.3\' into 4.4\n- [`9c06bf6`](https://github.com/symfony/http-foundation/commit/9c06bf65e4aa6b29c773cc5f88e2f548bb56b18a) Merge branch \'3.4\' into 4.3\n- [`5b932ee`](https://github.com/symfony/http-foundation/commit/5b932eed42c1f5172bd4ba46eef0525fce190502) Fix typo\n- [`760e8fb`](https://github.com/symfony/http-foundation/commit/760e8fb0b9d8c764ec10ccf7dd949b69bc59bd26) [HttpFoundation] fix pdo session handler for sqlsrv\n- [`a7ea28e`](https://github.com/symfony/http-foundation/commit/a7ea28e4c1184b48874ce4bbd348dbee3b3c9ada) Merge branch \'4.3\' into 4.4\n- [`5a40ccd`](https://github.com/symfony/http-foundation/commit/5a40ccddac8f1471738b9264a00c75acfbe686ac) Merge branch \'3.4\' into 4.3\n- [`7d2f82a`](https://github.com/symfony/http-foundation/commit/7d2f82af89da04 ...
#    'comment': {'url': 'https://api.github.com/repos/1357280829/larabbs/issues/comments/570779949',
#     'html_url': 'https://github.com/1357280829/larabbs/pull/2#issuecomment-570779949',
#     'issue_url': 'https://api.github.com/repos/1357280829/larabbs/issues/2',
#     'id': 570779949,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU3MDc3OTk0OQ==',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2020-01-04T12:03:32Z',
#     'updated_at': '2020-01-04T12:03:32Z',
#     'author_association': 'NONE',
#     'body': 'Looks like symfony/http-foundation is no longer updatable, so this is no longer needed.'}},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z'},
#  {'id': '11202379919',
#   'type': 'PushEvent',
#   'actor': {'id': 13794530,
#    'login': 'Mattia46',
#    'display_login': 'Mattia46',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mattia46',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13794530?'},
#   'repo': {'id': 229324931,
#    'name': 'Mattia46/WineNote-Sommelier',
#    'url': 'https://api.github.com/repos/Mattia46/WineNote-Sommelier'},
#   'payload': {'push_id': 4460340559,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/task/wine-preference-and-goBack-navigation',
#    'head': '8279cdb371e8b95855607ae35a37e46572aceb59',
#    'before': '7e96a9853fdb34d0a9036e23bd7c9e830f174ceb',
#    'commits': [{'sha': '8279cdb371e8b95855607ae35a37e46572aceb59',
#      'author': {'email': 'mattia.assogna@gmail.com', 'name': 'Mattia46'},
#      'message': 'refactor the Star component',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mattia46/WineNote-Sommelier/commits/8279cdb371e8b95855607ae35a37e46572aceb59'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z'},
#  {'id': '11202379918',
#   'type': 'CreateEvent',
#   'actor': {'id': 17812036,
#    'login': 'anledev',
#    'display_login': 'anledev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anledev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17812036?'},
#   'repo': {'id': 231756110,
#    'name': 'anledev/BackendTut',
#    'url': 'https://api.github.com/repos/anledev/BackendTut'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z'},
#  {'id': '11202379917',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 22429695,
#    'login': 'codecov[bot]',
#    'display_login': 'codecov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codecov[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22429695?'},
#   'repo': {'id': 7040500,
#    'name': 'falconry/falcon',
#    'url': 'https://api.github.com/repos/falconry/falcon'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/falconry/falcon/issues/1630',
#     'repository_url': 'https://api.github.com/repos/falconry/falcon',
#     'labels_url': 'https://api.github.com/repos/falconry/falcon/issues/1630/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/falconry/falcon/issues/1630/comments',
#     'events_url': 'https://api.github.com/repos/falconry/falcon/issues/1630/events',
#     'html_url': 'https://github.com/falconry/falcon/pull/1630',
#     'id': 545276667,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU5MjA4MDU1',
#     'number': 1630,
#     'title': 'Rewrites behaviour of Response.set_headers() method',
#     'user': {'login': 'mikeyusko',
#      'id': 13191999,
#      'node_id': 'MDQ6VXNlcjEzMTkxOTk5',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/13191999?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mikeyusko',
#      'html_url': 'https://github.com/mikeyusko',
#      'followers_url': 'https://api.github.com/users/mikeyusko/followers',
#      'following_url': 'https://api.github.com/users/mikeyusko/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mikeyusko/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mikeyusko/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mikeyusko/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mikeyusko/orgs',
#      'repos_url': 'https://api.github.com/users/mikeyusko/repos',
#      'events_url': 'https://api.github.com/users/mikeyusko/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mikeyusko/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-01-04T11:58:00Z',
#     'updated_at': '2020-01-04T12:03:32Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/falconry/falcon/pulls/1630',
#      'html_url': 'https://github.com/falconry/falcon/pull/1630',
#      'diff_url': 'https://github.com/falconry/falcon/pull/1630.diff',
#      'patch_url': 'https://github.com/falconry/falcon/pull/1630.patch'},
#     'body': '# Summary of Changes\r\n\r\nChanged behavior in `Response.set_headers()` the method, now we\'re checking for interface compliance, instead of check whether an object is an instance of ``dict``.\r\n\r\nAlso, new changes allow passing a custom class which will be setting headers for a response.\r\ne.g\r\n```\r\nclass CustomHeaders:\r\n    # ... custom flow etc.\r\n    def items(self):\r\n        return [(\'header\', \'value\')]  # or return {\'header\': \'value\'}\r\n\r\n\r\nclass Resource:\r\n    def on_get(self, req, resp):\r\n        custom_headers = CustomHeaders()\r\n\r\n        resp.set_headers(custom_headers)\r\n```\r\n\r\n# Related Issues\r\n\r\nhttps://github.com/falconry/falcon/issues/1546\r\n\r\nPlease reference here any issue #\'s that are relevant to this PR, or simply enter "N/A" if this PR does not relate to any existing issues.\r\n\r\n# Pull Request Checklist\r\n\r\nThis is just a reminder about the most common mistakes.  Please make sure that you tick all *appropriate* boxes.  But please read our [contribution guide](https://github.com/falconry/falcon/blob/master/CONTRIBUTING.md) at least once; it will save you a few review cycles!\r\n\r\nIf an item doesn\'t apply to your pull request, **check it anyway** to make it apparent that there\'s nothing to do.\r\n\r\n- [x] Added **tests** for changed code.\r\n- [ ] Prefixed code comments with GitHub nick and an appropriate prefix.\r\n- [x] Coding style is consistent with the rest of the framework.\r\n- [x] Updated **documentation** for changed code.\r\n    - [ ] Added docstrings for any new classes, functions, or modules.\r\n    - [x] Updated docstrings for any modifications to existing code.\r\n    - [ ] Added references to new classes, functions, or modules to the relevant RST file under `docs/`.\r\n    - [ ] Updated all relevant supporting documentation files under `docs/`.\r\n    - [ ] A copyright notice is included at the top of any new modules (using your own name or the name of your organization).\r\n    - [ ] Changed/added classes/methods/functions have appropriate `versionadded`, `versionchanged`, or `deprecated` [directives](http://www.sphinx-doc.org/en/stable/usage/restructuredtext/directives.html?highlight=versionadded#directive-versionadded).\r\n- [ ] Changes (and possible deprecations) have [towncrier](https://pypi.org/project/towncrier/) news fragments under `docs/_newsfragments/`. (Run `towncrier --draft` to ensure it renders correctly.)\r\n\r\nIf you have *any* questions to *any* of the points above, just **submit and ask**! This checklist is here to *help* you, not to deter you from contributing!\r\n\r\n*PR template inspired by the attrs project.*\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/falconry/falcon/issues/comments/570779947',
#     'html_url': 'https://github.com/falconry/falcon/pull/1630#issuecomment-570779947',
#     'issue_url': 'https://api.github.com/repos/falconry/falcon/issues/1630',
#     'id': 570779947,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU3MDc3OTk0Nw==',
#     'user': {'login': 'codecov[bot]',
#      'id': 22429695,
#      'node_id': 'MDM6Qm90MjI0Mjk2OTU=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/in/254?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/codecov%5Bbot%5D',
#      'html_url': 'https://github.com/apps/codecov',
#      'followers_url': 'https://api.github.com/users/codecov%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/codecov%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/codecov%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/codecov%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/codecov%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/codecov%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/codecov%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/codecov%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/codecov%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2020-01-04T12:03:32Z',
#     'updated_at': '2020-01-04T12:03:32Z',
#     'author_association': 'NONE',
#     'body': '# [Codecov](https://codecov.io/gh/falconry/falcon/pull/1630?src=pr&el=h1) Report\n> Merging [#1630](https://codecov.io/gh/falconry/falcon/pull/1630?src=pr&el=desc) into [master](https://codecov.io/gh/falconry/falcon/commit/79c33e91d1c21fed171bf6fc341b56f115bfc447?src=pr&el=desc) will **not change** coverage.\n> The diff coverage is `100%`.\n\n[![Impacted file tree graph](https://codecov.io/gh/falconry/falcon/pull/1630/graphs/tree.svg?width=650&token=zOtkfNQ3h6&height=150&src=pr)](https://codecov.io/gh/falconry/falcon/pull/1630?src=pr&el=tree)\n\n```diff\n@@          Coverage Diff           @@\n##           master   #1630   +/-   ##\n======================================\n  Coverage     100%    100%           \n======================================\n  Files          40      40           \n  Lines        2692    2693    +1     \n  Branches      397     397           \n======================================\n+ Hits         2692    2693    +1\n```\n\n\n| [Impacted Files](https://codecov.io/gh/falconry/falcon/pull/1630?src=pr&el=tree) | Coverage Δ | |\n|---|---|---|\n| [falcon/response.py](https://codecov.io/gh/falconry/falcon/pull/1630/diff?src=pr&el=tree#diff-ZmFsY29uL3Jlc3BvbnNlLnB5) | `100% <100%> (ø)` | :arrow_up: |\n\n------\n\n[Continue to review full report at Codecov](https://codecov.io/gh/falconry/falcon/pull/1630?src=pr&el=continue).\n> **Legend** - [Click here to learn more](https://docs.codecov.io/docs/codecov-delta)\n> `Δ = absolute <relative> (impact)`, `ø = not affected`, `? = missing data`\n> Powered by [Codecov](https://codecov.io/gh/falconry/falcon/pull/1630?src=pr&el=footer). Last update [79c33e9...cbd26fa](https://codecov.io/gh/falconry/falcon/pull/1630?src=pr&el=lastupdated). Read the [comment docs](https://docs.codecov.io/docs/pull-request-comments).\n'}},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z',
#   'org': {'id': 11353642,
#    'login': 'falconry',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/falconry',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11353642?'}},
#  {'id': '11202379916',
#   'type': 'IssuesEvent',
#   'actor': {'id': 4464333,
#    'login': 'lindyhopchris',
#    'display_login': 'lindyhopchris',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lindyhopchris',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4464333?'},
#   'repo': {'id': 197137338,
#    'name': 'cloudcreativity/laravel-stripe',
#    'url': 'https://api.github.com/repos/cloudcreativity/laravel-stripe'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/cloudcreativity/laravel-stripe/issues/3',
#     'repository_url': 'https://api.github.com/repos/cloudcreativity/laravel-stripe',
#     'labels_url': 'https://api.github.com/repos/cloudcreativity/laravel-stripe/issues/3/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/cloudcreativity/laravel-stripe/issues/3/comments',
#     'events_url': 'https://api.github.com/repos/cloudcreativity/laravel-stripe/issues/3/events',
#     'html_url': 'https://github.com/cloudcreativity/laravel-stripe/issues/3',
#     'id': 527526153,
#     'node_id': 'MDU6SXNzdWU1Mjc1MjYxNTM=',
#     'number': 3,
#     'title': 'Invalid alias name',
#     'user': {'login': 'jacksontong',
#      'id': 7871218,
#      'node_id': 'MDQ6VXNlcjc4NzEyMTg=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/7871218?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jacksontong',
#      'html_url': 'https://github.com/jacksontong',
#      'followers_url': 'https://api.github.com/users/jacksontong/followers',
#      'following_url': 'https://api.github.com/users/jacksontong/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jacksontong/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jacksontong/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jacksontong/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jacksontong/orgs',
#      'repos_url': 'https://api.github.com/users/jacksontong/repos',
#      'events_url': 'https://api.github.com/users/jacksontong/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jacksontong/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1453355778,
#       'node_id': 'MDU6TGFiZWwxNDUzMzU1Nzc4',
#       'url': 'https://api.github.com/repos/cloudcreativity/laravel-stripe/labels/bug',
#       'name': 'bug',
#       'color': 'd73a4a',
#       'default': True,
#       'description': "Something isn't working"}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2019-11-23T08:01:46Z',
#     'updated_at': '2020-01-04T12:03:32Z',
#     'closed_at': '2020-01-04T12:03:32Z',
#     'author_association': 'NONE',
#     'body': 'https://github.com/cloudcreativity/laravel-stripe/blob/develop/composer.json#L51\r\nThe current alias name is "JsonApi" which I think is inappropriate, of couse I can override it in my config file.\r\nbtw: great project.'}},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z',
#   'org': {'id': 12550113,
#    'login': 'cloudcreativity',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cloudcreativity',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12550113?'}},
#  {'id': '11202379906',
#   'type': 'IssuesEvent',
#   'actor': {'id': 9768364,
#    'login': 'ArsNatura',
#    'display_login': 'ArsNatura',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ArsNatura',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9768364?'},
#   'repo': {'id': 31270962,
#    'name': 'kodi-pvr/pvr.vuplus',
#    'url': 'https://api.github.com/repos/kodi-pvr/pvr.vuplus'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/kodi-pvr/pvr.vuplus/issues/268',
#     'repository_url': 'https://api.github.com/repos/kodi-pvr/pvr.vuplus',
#     'labels_url': 'https://api.github.com/repos/kodi-pvr/pvr.vuplus/issues/268/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/kodi-pvr/pvr.vuplus/issues/268/comments',
#     'events_url': 'https://api.github.com/repos/kodi-pvr/pvr.vuplus/issues/268/events',
#     'html_url': 'https://github.com/kodi-pvr/pvr.vuplus/issues/268',
#     'id': 545277165,
#     'node_id': 'MDU6SXNzdWU1NDUyNzcxNjU=',
#     'number': 268,
#     'title': 'Kodi crashes after splash screen',
#     'user': {'login': 'ArsNatura',
#      'id': 9768364,
#      'node_id': 'MDQ6VXNlcjk3NjgzNjQ=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/9768364?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ArsNatura',
#      'html_url': 'https://github.com/ArsNatura',
#      'followers_url': 'https://api.github.com/users/ArsNatura/followers',
#      'following_url': 'https://api.github.com/users/ArsNatura/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ArsNatura/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ArsNatura/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ArsNatura/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ArsNatura/orgs',
#      'repos_url': 'https://api.github.com/users/ArsNatura/repos',
#      'events_url': 'https://api.github.com/users/ArsNatura/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ArsNatura/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-01-04T12:03:31Z',
#     'updated_at': '2020-01-04T12:03:31Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': 'I\'ve tested with Kodi 18.5 in Mac OS and Fire Stick 4K (Android 7 - ARM 32bit). Both with default settings.xml (just changing <setting id="host"> to the IP of my Vu+ Zero 4K) with the same result.\r\n\r\nI\'ve installed the add-on via Kodi resopitory.\r\n\r\nThis is the log from my Mac:\r\n-----------------------------------------------------------------------\r\n2020-01-04 12:48:52.812 T:4741447104  NOTICE: Starting Kodi (18.5 Git:20191116-37f51f6e63). Platform: OS X x86 64-bit\r\n2020-01-04 12:48:52.812 T:4741447104  NOTICE: Using Release Kodi x64 build\r\n2020-01-04 12:48:52.812 T:4741447104  NOTICE: Kodi compiled 2019-11-16 by Clang 9.0.0 (clang-900.0.37) for OS X x86 64-bit version 10.9.0 (1090)\r\n2020-01-04 12:48:52.812 T:4741447104  NOTICE: Running on Apple Inc. MacBookAir7,2 with OS X 10.15.2, kernel: Darwin x86 64-bit version 19.2.0\r\n\r\n[...]\r\n\r\n2020-01-04 12:48:56.013 T:123145322876928  NOTICE: AddOnLog: Enigma2 Client: pvr.vuplus - ConnectionEstablished Connection Established with Enigma2 device...\r\n2020-01-04 12:48:56.013 T:123145322876928  NOTICE: AddOnLog: Enigma2 Client: pvr.vuplus - ConnectionEstablished - VU+ Addon Configuration options\r\n2020-01-04 12:48:56.014 T:123145322876928  NOTICE: AddOnLog: Enigma2 Client: pvr.vuplus - ConnectionEstablished - Hostname: \'192.168.1.222\'\r\n2020-01-04 12:48:56.014 T:123145322876928  NOTICE: AddOnLog: Enigma2 Client: pvr.vuplus - ConnectionEstablished - WebPort: \'80\'\r\n2020-01-04 12:48:56.014 T:123145322876928  NOTICE: AddOnLog: Enigma2 Client: pvr.vuplus - ConnectionEstablished - StreamPort: \'8001\'\r\n2020-01-04 12:48:56.014 T:123145322876928  NOTICE: AddOnLog: Enigma2 Client: pvr.vuplus - ConnectionEstablished Use HTTPS: \'false\'\r\n2020-01-04 12:48:56.062 T:123145322876928  NOTICE: AddOnLog: Enigma2 Client: pvr.vuplus - LoadDeviceInfo - DeviceInfo\r\n2020-01-04 12:48:56.062 T:123145322876928  NOTICE: AddOnLog: Enigma2 Client: pvr.vuplus - LoadDeviceInfo - E2EnigmaVersion: 2018-12-10-master\r\n2020-01-04 12:48:56.062 T:123145322876928  NOTICE: AddOnLog: Enigma2 Client: pvr.vuplus - LoadDeviceInfo - E2ImageVersion: 3.0.8.0\r\n2020-01-04 12:48:56.063 T:123145322876928  NOTICE: AddOnLog: Enigma2 Client: pvr.vuplus - LoadDeviceInfo - E2DistroName: BlackHole\r\n2020-01-04 12:48:56.063 T:123145322876928  NOTICE: AddOnLog: Enigma2 Client: pvr.vuplus - LoadDeviceInfo - E2WebIfVersion: OWIF 1.2.6\r\n2020-01-04 12:48:56.063 T:123145322876928  NOTICE: AddOnLog: Enigma2 Client: pvr.vuplus - LoadDeviceInfo - E2DeviceName: Zero4K\r\n2020-01-04 12:48:56.063 T:123145322876928  NOTICE: AddOnLog: Enigma2 Client: pvr.vuplus - LoadDeviceInfo - ServerVersion: OWIF 1.2.6 - BlackHole (3.0.8.0/2018-12-10-master)\r\n2020-01-04 12:48:56.063 T:123145322876928  NOTICE: AddOnLog: Enigma2 Client: pvr.vuplus - LoadDeviceInfo - AddonVersion: 3.28.9\r\n\r\n[end of the log]\r\n\r\nAm I doing something wrong?\r\nThanks for your time.'}},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z',
#   'org': {'id': 11259403,
#    'login': 'kodi-pvr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kodi-pvr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11259403?'}},
#  {'id': '11202379907',
#   'type': 'PushEvent',
#   'actor': {'id': 9110954,
#    'login': 'wmschram',
#    'display_login': 'wmschram',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wmschram',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9110954?'},
#   'repo': {'id': 230953323,
#    'name': 'project-carmeet/project-carmeet',
#    'url': 'https://api.github.com/repos/project-carmeet/project-carmeet'},
#   'payload': {'push_id': 4460340555,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature/jumbotron-types',
#    'head': '3a258e1aaa13fb63185d82061cf767a4b0622013',
#    'before': '54bded7d74c94338e1462dc2be6815e03f834013',
#    'commits': [{'sha': '3a258e1aaa13fb63185d82061cf767a4b0622013',
#      'author': {'email': 'info@martijnschram.com', 'name': 'Martijn'},
#      'message': '#33 new color overlay, fixed position navbar on desktop',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/project-carmeet/project-carmeet/commits/3a258e1aaa13fb63185d82061cf767a4b0622013'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z',
#   'org': {'id': 59370736,
#    'login': 'project-carmeet',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/project-carmeet',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59370736?'}},
#  {'id': '11202379908',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 215852340,
#    'name': 'bbq-beets/starter-packages',
#    'url': 'https://api.github.com/repos/bbq-beets/starter-packages'},
#   'payload': {'push_id': 4460340557,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '70edc5ca567a1e5f8c01625747735f5773bbc03f',
#    'before': 'ce03d4bf98c39895a3ebbdf52d659e2627607d02',
#    'commits': [{'sha': '70edc5ca567a1e5f8c01625747735f5773bbc03f',
#      'author': {'email': 'action@github.com', 'name': 'GitHub Action'},
#      'message': 'Add changes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bbq-beets/starter-packages/commits/70edc5ca567a1e5f8c01625747735f5773bbc03f'}]},
#   'public': True,
#   'created_at': '2020-01-04T12:03:32Z',
#   'org': {'id': 33435682,
#    'login': 'bbq-beets',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/bbq-beets',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33435682?'}}]

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0'},
#  'origin': '220.136.68.104, 220.136.68.104',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0'},
#  'json': None,
#  'origin': '36.228.115.188, 36.228.115.188',
#  'url': 'https://httpbin.org/post'}

# %%
#自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
import requests

r1 = requests.get('https://data.gov.tw/dataset/25768')
r1.text
# Out:
# '\r\n<!DOCTYPE html>\n<html lang="zh-hant" dir="ltr">\n<head profile="http://www.w3.org/1999/xhtml/vocab">\n  <meta charset="utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta name="MobileOptimized" content="width" />\n<meta name="HandheldFriendly" content="true" />\n<meta name="viewport" content="width = device-width, initial-scale = 1.0, minimum-scale = 1, maximum-scale = 1, user-scalable = no" />\n<link href="/sites/datagov/themes/thetheme/images/apple-touch-icon-60x60.png" rel="apple-touch-icon" />\n<link href="/sites/datagov/themes/thetheme/images/apple-touch-icon-76x76.png" rel="apple-touch-icon" />\n<link href="/sites/datagov/themes/thetheme/images/apple-touch-icon-120x120.png" rel="apple-touch-icon" />\n<link href="/sites/datagov/themes/thetheme/images/apple-touch-icon-152x152.png" rel="apple-touch-icon" />\n<link rel="shortcut icon" href="https://data.gov.tw/sites/datagov/themes/thetheme/favicon.ico" type="image/vnd.microsoft.icon" />\n<meta name="generator" content="Drupal 7 (https://www.drupal.org)" />\n<link rel="canonical" href="https://data.gov.tw/dataset/25768" />\n<link rel="shortlink" href="https://data.gov.tw/node/25768" />\n  <title>即時水位資料 | 政府資料開放平臺</title>\n  <link type="text/css" rel="stylesheet" href="https://data.gov.tw/sites/datagov/files/css/css_lQaZfjVpwP_oGNqdtWCSpJT1EMqXdMiU84ekLLxQnc4.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://data.gov.tw/sites/datagov/files/css/css_3BZ82PZOh6f2x_mflRUBrPS7QDwKgzJR_k0u1IbskFA.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://data.gov.tw/sites/datagov/files/css/css_1wktTPU-ImO7gctAnV9GvGxfUUvga8ioN0lsemqNOg8.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://data.gov.tw/sites/datagov/modules/thesite/datagov/lib/css/chatbot.css?q1zgzm" media="all" />\n<link type="text/css" rel="stylesheet" href="https://data.gov.tw/sites/datagov/files/css/css_lhZ2r95cVv6XPZeCq2neqJ2WkJfOx4FGwB5NFslhk94.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://data.gov.tw/sites/datagov/files/css/css_vV8xwRUrJZULNsljz9fbUHnBI-1KYuK6PMC8IkW0Sus.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://cdn.jsdelivr.net/gh/fancyapps/fancybox@3.5.7/dist/jquery.fancybox.min.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://data.gov.tw/sites/datagov/files/css/css_QvnXtpGtUuoqfCtjENkiJbaXWreFw2xX0LfKCTPnjBE.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://data.gov.tw/sites/datagov/files/css/css_Nlsb2kmxE69uxwiCu3IHTT2b_eHe0IuxaSaW121AVhs.css" media="all" />\n\n<!--[if lte IE 7]>\n<link type="text/css" rel="stylesheet" href="https://data.gov.tw/sites/datagov/themes/thetheme/css/ie.css?q1zgzm" media="all" />\n<![endif]-->\n  <script src="https://data.gov.tw/sites/datagov/files/js/js_xvYJgU6LChHqbcSh4y1AvdXfD5QBIwT3GVGVUeuksbM.js"></script>\n<script src="https://data.gov.tw/sites/datagov/files/js/js_7altEs-5sVDGQ-3OBgAG0XmMkBOO5rh18rXRvUyb3ZI.js"></script>\n<script>document.createElement( "picture" );</script>\n<script src="https://data.gov.tw/sites/datagov/files/js/js_2L-Sn8p9cop_F3_mHtA3oxRmwJq6qaBxlrgArbHwJdo.js"></script>\n<script defer="defer" src="https://data.gov.tw/sites/datagov/modules/thesite/dgsubscription/js/scripts.js?1578213700"></script>\n<script defer="defer" src="https://data.gov.tw/sites/datagov/modules/thesite/dgsubscription/js/jquery.min.js?1578213700"></script>\n<script src="https://cdnjs.cloudflare.com/ajax/libs/fancybox/3.5.7/jquery.fancybox.js"></script>\n<script defer="defer" src="https://data.gov.tw/sites/datagov/modules/thesite/datagov/lib/js/chatbot.js?1578213700"></script>\n<script src="https://data.gov.tw/sites/datagov/files/js/js_gPqjYq7fqdMzw8-29XWQIVoDSWTmZCGy9OqaHppNxuQ.js"> ...
