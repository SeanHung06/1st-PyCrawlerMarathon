# %%
import requests
r = requests.get('https://www.dcard.tw/_api/forums/job/posts?popular=true')
# 想要爬資料的⽬目標網址
response = r.text
print(response)
# Out:
# [{"id":225578807,"title":"<請先點我> 工作板＆實習、打工職缺刊登說明","excerpt":"工作板主要供分享職場工作心得、面試、正職、招考過程分享、各類型工作內容介紹、勞工工作權益與相關法案議題討論相關文章。文章發文後請加上話題，如：經驗分享、職業介紹、勞工權益、徵才等....，「實習職缺/刊登」請點：","anonymousSchool":false,"anonymousDepartment":true,"pinned":true,"forumId":"6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444","replyId":null,"createdAt":"2017-01-01T06:27:39.650Z","updatedAt":"2018-07-27T00:18:35.980Z","commentCount":34,"likeCount":665,"withNickname":true,"tags":[],"topics":["工作板","Dcard公告","實習職缺","打工職缺"],"meta":{},"forumName":"工作","forumAlias":"job","gender":"D","school":"客服小天使","department":"dcard_support_2","replyTitle":null,"mediaMeta":[],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":663},{"id":"aa0d425f-d530-4478-9a77-fe3aedc79eea","count":1},{"id":"e8e6bc5d-41b0-4129-b134-97507523d7ff","count":1}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"layout":"classic","withImages":false,"withVideos":false,"media":[],"reportReasonText":"","postAvatar":""},{"id":232822218,"title":
# ...

# %%
#1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

import json
data = json.loads(response)
# 利用 json 解析網⾴內容

#一次回傳30筆資料
for d in data:
    print('每一筆資料包含的欄位:')
    for i in d:
        print(i)
    break
# Out:
# 每一筆資料包含的欄位:
# id
# title
# excerpt
# anonymousSchool
# anonymousDepartment
# pinned
# forumId
# replyId
# createdAt
# updatedAt
# commentCount
# likeCount
# withNickname
# tags
# topics
# meta
# forumName
# forumAlias
# gender
# school
# department
# replyTitle
# mediaMeta
# reactions
# hidden
# customStyle
# isSuspiciousAccount
# layout
# withImages
# withVideos
# media
# reportReasonText
# postAvatar

# %%
#2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
for d in data:
    print('標題:',d['title'],'\n貼文時間:',d['createdAt'],'\n留言人數:',d['commentCount'],'\n按讚人數:',d['likeCount'],'\n')
# Out:
# 標題: <請先點我> 工作板＆實習、打工職缺刊登說明
# 貼文時間: 2017-01-01T06:27:39.650Z
# 留言人數: 34
# 按讚人數: 665
#
# 標題: 20200105長榮空服招募
# 貼文時間: 2020-01-04T04:43:44.613Z
# 留言人數: 35
# 按讚人數: 36
#
# 標題: 論資訊重要性
# 貼文時間: 2020-01-04T06:32:19.936Z
# 留言人數: 15
# 按讚人數: 22
#
# 標題: 職場搞排擠，還是離開好
# 貼文時間: 2020-01-04T14:36:38.972Z
# 留言人數: 0
# 按讚人數: 19
#
# 標題: 提出離職的最佳時機
# 貼文時間: 2020-01-04T03:27:00.325Z
# 留言人數: 8
# 按讚人數: 18
#
# 標題: 我的媽媽被職場霸凌
# 貼文時間: 2020-01-04T14:10:34.027Z
# 留言人數: 5
# 按讚人數: 16
#
# 標題: 工作
# 貼文時間: 2020-01-04T00:52:17.264Z
# 留言人數: 3
# 按讚人數: 15
#
# 標題: 找正職好難
# 貼文時間: 2020-01-04T11:13:41.561Z
# 留言人數: 2
# 按讚人數: 13
#
# 標題: 這篇文章讓我忍不住想嗆原PO
# 貼文時間: 2020-01-05T01:31:22.217Z
# 留言人數: 1
# 按讚人數: 12
#
# 標題: 百萬年薪很簡單？
# 貼文時間: 2020-01-04T17:52:49.188Z
# 留言人數: 13
# 按讚人數: 11
#
# 標題: 面試官抱怨大學生求職觀念
# 貼文時間: 2020-01-04T15:03:20.006Z
# 留言人數: 5
# 按讚人數: 11
#
# 標題: 投票日出勤到底是給雙倍薪資還是加班費？！
# 貼文時間: 2020-01-04T05:44:42.429Z
# 留言人數: 13
# 按讚人數: 11
#
# 標題: 經理職場霸凌
# 貼文時間: 2020-01-04T08:56:05.028Z
# 留言人數: 8
# 按讚人數: 10
#
# 標題: 台灣經濟那麼好 不用出國打工
# ...

# %%
#3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

r1 = requests.get('https://www.dcard.tw/_api/forums/job/posts?popular=false')
response1 = r1.text
data1 = json.loads(response1)

x= 0 
y=0
x1=0
y1=0
for d in data:
    x = x+ d['commentCount']
    y+=d['likeCount']
for c in data1:
    x1 = x1+ d['commentCount']
    y1+=d['likeCount']
print('熱門「平均留言人數」:',x/30,'\n熱門「平均按讚人數」:',y/30)
print('非熱門「平均留言人數」:',x1/30,'\n非熱門「平均按讚人數」:',y1/30)
# Out:
# 熱門「平均留言人數」: 8.7
# 熱門「平均按讚人數」: 31.166666666666668
# 非熱門「平均留言人數」: 8.0
# 非熱門「平均按讚人數」: 3.0
