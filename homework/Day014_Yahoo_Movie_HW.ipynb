# %% [markdown]
# # YAHOO電影爬蟲練習
# ## 練習爬取電影放映資訊。必須逐步獲取電影的代號、放映地區、放映日期後，再送出查詢給伺服器。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先搜尋全部的電影代號(ID)資訊

# %%
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
html = soup.find("select", attrs={'class':'movie_name'})
#print(html)
movie_item = html.find_all("option", attrs={'data-name':re.compile('.*')})
Movies = []
for p in movie_item:
    print("Movie: %s, ID: %s" % (p["data-name"], p["value"]))
    movie = {}  
    movie['data-name'] = p['data-name']
    movie['value'] = p['value']
    Movies.append(movie)
#print(Movies)
# Out:
# Movie: 我們的7日戰爭, ID: 10453
# Movie: 肥龍過江, ID: 10449
# Movie: 岳父受死吧, ID: 10446
# Movie: 殺手撿到槍, ID: 10423
# Movie: 你的情歌, ID: 10407
# Movie: 紳士追殺令, ID: 10317
# Movie: 杜立德, ID: 10316
# Movie: 喜從天降, ID: 10123
# Movie: 深海終劫站, ID: 10230
# Movie: 她們, ID: 10202
# Movie: 變身特務, ID: 9008
# Movie: 然後我們跳了舞, ID: 10451
# Movie: 巧虎電影：英雄遊樂園, ID: 10429
# Movie: 在黑暗中漫舞：20週年數位修復版, ID: 10428
# Movie: 哥哥戀愛了，我怎麼辦！？, ID: 10414
# Movie: 青春催落去, ID: 10404
# Movie: 姊魅, ID: 10403
# Movie: 不完美的正義, ID: 10243
# Movie: 絕地戰警FOR LIFE, ID: 10242
# Movie: 大監獄行動, ID: 10450
# Movie: 惡靈20, ID: 10444
# Movie: 魯邦三世 The First, ID: 10355
# Movie: 重磅腥聞, ID: 10320
# Movie: 別告訴她, ID: 10382
# Movie: 真愛裁會贏, ID: 10362
# Movie: 兔嘲男孩, ID: 10283
# Movie: 海上鋼琴師4K數位修復, ID: 10425
# Movie: 倒數計死, ID: 10390
# Movie: 潛艦追緝, ID: 10333
# Movie: 霹靂嬌娃, ID: 10124
# Movie: 白頭山：半島浩劫, ID: 10354
# Movie: 茱蒂, ID: 10112
# Movie: 燃燒女子的畫像, ID: 10069
# Movie: 葉問4：完結篇, ID: 9890
# Movie: STAR WARS : 天行者的崛起, ID: 10225
# Movie: 黑熊來了, ID: 10357
# Movie: 巴黎小情聖, ID: 10329
# Movie: 野蠻遊戲：全面晉級, ID: 10134
# Movie: 懸案密碼前傳：瓶中信, ID: 10254
# Movie: 布魯克林孤兒, ID: 10224
# Movie: 暴走曼哈頓, ID: 10044
# Movie: 鋒迴路轉, ID: 10258
# Movie: 賽道狂人, ID: 10097
# Movie: 冰雪奇緣2, ID: 9597
# Movie: 萬萬沒想到, ID: 10281
# Movie: 新聞記者, ID: 10217
# Movie: 決戰中途島, ID: 10130
# Movie: 安眠醫生, ID: 10098
# Movie: 魔鬼終結者：黑暗宿命, ID: 10067
# Movie: 阿達一族, ID: 9992
# Movie: 陪你很久很久, ID: 10160
# Movie: 雙子殺手, ID: 10017
# Movie: 黑魔女2, ID: 10262
# Movie: 江湖無難事, ID: 10241
# Movie: 小丑, ID: 9949
# Movie: 無間行動, ID: 10155
# Movie: 囧媽的極地任務, ID: 7772
# Movie: 返校, ID: 10109
# Movie: 天氣之子, ID: 10091
# Movie: 從前，有個好萊塢, ID: 9884
# Movie: 獅子王, ID: 9116
# Movie: 寄生上流, ID: 10020
# Movie: 玩具總動員4, ID: 9924
# Movie: 毀滅者, ID: 9405
# Movie: 庫爾斯克號：深海救援, ID: 9134
# Movie: 厄夜追緝令, ID: 9589
# Movie: 苦兒流浪記, ID: 9538
# Movie: 活個精彩, ID: 9394
# Movie: 限時好友, ID: 9578
# Movie: 祝你忌日快樂, ID: 9568
# Movie: 艾莉塔：戰鬥天使, ID: 8553
# Movie: 馴龍高手3, ID: 8350
# Movie: 幸福綠皮書, ID: 9150
# Movie: 一首搖滾上月球, ID: 4887
# Movie: 錢不夠用2, ID: 3026

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 9008

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
    
#print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 新北市, 代號(area_id): 8
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 新竹, 代號(area_id): 20
# 放映地區: 苗栗, 代號(area_id): 15
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 一月 25
# 一月 26
# 一月 27
# 一月 28
# 一月 29

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2020-01-25"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
#print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})
print(html)
# Out:
# [<ul class="area_time _c jq_area_time" data-theater_name="國賓影城(台北長春廣場)" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=29" data-theater_url="http://www.ambassador.com.tw/" id="theater_id_29">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=29">國賓影城(台北長春廣場)</a>
# <span>02-25155755</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="10:50" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822786" name="schedule_list" type="radio" value="2020-01-25 10:50:00"/>
# <label class="" for="72822786">10:50</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="12:45" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822787" name="schedule_list" type="radio" value="2020-01-25 12:45:00"/>
# <label class="" for="72822787">12:45</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="14:40" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822788" name="schedule_list" type="radio" value="2020-01-25 14:40:00"/>
# <label class="" for="72822788">14:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="16:40" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822789" name="schedule_list" type="radio" value="2020-01-25 16:40:00"/>
# <label class="" for="72822789">16:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="18:35" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822790" name="schedule_list" type="radio" value="2020-01-25 18:35:00"/>
# <label class="" for="72822790">18:35</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="20:30" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822791" name="schedule_list" type="radio" value="2020-01-25 20:30:00"/>
# <label class="" for="72822791">20:30</label>
# </div>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> <span class="tapB">中文</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="11:30" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822795" name="schedule_list" type="radio" value="2020-01-25 11:30:00"/>
# <label class="" for="72822795">11:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="15:25" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822796" name="schedule_list" type="radio" value="2020-01-25 15:25:00"/>
# <label class="" for="72822796">15:25</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="欣欣秀泰影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=30" data-theater_url="http://www.showtimes.com.tw/" id="theater_id_30">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=30">欣欣秀泰影城</a>
# <span>02-25371889</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> <span class="tapB">中文</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="10:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822878" name="schedule_list" type="radio" value="2020-01-25 10:20:00"/>
# <label class="" for="72822878">10:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="12:25" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822879" name="schedule_list" type="radio" value="2020-01-25 12:25:00"/>
# <label class="" for="72822879">12:25</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="14:30" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822880" name="schedule_list" type="radio" value="2020-01-25 14:30:00"/>
# <label class="" for="72822880">14:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="16:35" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822881" name="schedule_list" type="radio" value="2020-01-25 16:35:00"/>
# <label class="" for="72822881">16:35</label>
# </div>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="11:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822863" name="schedule_list" type="radio" value="2020-01-25 11:20:00"/>
# <label class="" for="72822863">11:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="13:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822864" name="schedule_list" type="radio" value="2020-01-25 13:20:00"/>
# <label class="" for="72822864">13:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="15:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822865" name="schedule_list" type="radio" value="2020-01-25 15:20:00"/>
# <label class="" for="72822865">15:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="17:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822866" name="schedule_list" type="radio" value="2020-01-25 17:20:00"/>
# <label class="" for="72822866">17:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="19:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822867" name="schedule_list" type="radio" value="2020-01-25 19:20:00"/>
# <label class="" for="72822867">19:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="21:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822868" name="schedule_list" type="radio" value="2020-01-25 21:20:00"/>
# <label class="" for="72822868">21:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="23:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822869" name="schedule_list" type="radio" value="2020-01-25 23:20:00"/>
# <label class="" for="72822869">23:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.26" data-movie_time="01:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822870" name="schedule_list" type="radio" value="2020-01-26 01:20:00"/>
# <label class="" for="72822870">01:20</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="華威天母影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=33" data-theater_url="http://www.woviecinemas.com.tw/" id="theater_id_33">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=33">華威天母影城</a>
# <span>02-28763300</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> <span class="tapB">中文</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="10:10" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822929" name="schedule_list" type="radio" value="2020-01-25 10:10:00"/>
# <label class="" for="72822929">10:10</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="12:15" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822930" name="schedule_list" type="radio" value="2020-01-25 12:15:00"/>
# <label class="" for="72822930">12:15</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="14:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822931" name="schedule_list" type="radio" value="2020-01-25 14:20:00"/>
# <label class="" for="72822931">14:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="16:25" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822932" name="schedule_list" type="radio" value="2020-01-25 16:25:00"/>
# <label class="" for="72822932">16:25</label>
# </div>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="10:50" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822922" name="schedule_list" type="radio" value="2020-01-25 10:50:00"/>
# <label class="" for="72822922">10:50</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="12:55" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822923" name="schedule_list" type="radio" value="2020-01-25 12:55:00"/>
# <label class="" for="72822923">12:55</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="15:00" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822924" name="schedule_list" type="radio" value="2020-01-25 15:00:00"/>
# <label class="" for="72822924">15:00</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="17:05" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822925" name="schedule_list" type="radio" value="2020-01-25 17:05:00"/>
# <label class="" for="72822925">17:05</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="19:10" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822926" name="schedule_list" type="radio" value="2020-01-25 19:10:00"/>
# <label class="" for="72822926">19:10</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="21:15" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822927" name="schedule_list" type="radio" value="2020-01-25 21:15:00"/>
# <label class="" for="72822927">21:15</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="23:25" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822928" name="schedule_list" type="radio" value="2020-01-25 23:25:00"/>
# <label class="" for="72822928">23:25</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="國賓大戲院(西門)" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=37" data-theater_url="http://www.ambassador.com.tw/" id="theater_id_37">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=37">國賓大戲院(西門)</a>
# <span>02-23611222</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="10:30" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822613" name="schedule_list" type="radio" value="2020-01-25 10:30:00"/>
# <label class="" for="72822613">10:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="14:30" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822614" name="schedule_list" type="radio" value="2020-01-25 14:30:00"/>
# <label class="" for="72822614">14:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="18:30" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822615" name="schedule_list" type="radio" value="2020-01-25 18:30:00"/>
# <label class="" for="72822615">18:30</label>
# </div>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> <span class="tapB">中文</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="12:30" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822616" name="schedule_list" type="radio" value="2020-01-25 12:30:00"/>
# <label class="" for="72822616">12:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="16:30" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822617" name="schedule_list" type="radio" value="2020-01-25 16:30:00"/>
# <label class="" for="72822617">16:30</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="國賓影城(微風廣場)" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=47" data-theater_url="http://www.ambassador.com.tw/" id="theater_id_47">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=47">國賓影城(微風廣場)</a>
# <span>02-87721234</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="10:50" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822517" name="schedule_list" type="radio" value="2020-01-25 10:50:00"/>
# <label class="" for="72822517">10:50</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="14:40" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822518" name="schedule_list" type="radio" value="2020-01-25 14:40:00"/>
# <label class="" for="72822518">14:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="16:40" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822519" name="schedule_list" type="radio" value="2020-01-25 16:40:00"/>
# <label class="" for="72822519">16:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="18:40" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822520" name="schedule_list" type="radio" value="2020-01-25 18:40:00"/>
# <label class="" for="72822520">18:40</label>
# </div>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> <span class="tapB">中文</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="12:45" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822521" name="schedule_list" type="radio" value="2020-01-25 12:45:00"/>
# <label class="" for="72822521">12:45</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="哈拉影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=50" data-theater_url="" id="theater_id_50">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=50">哈拉影城</a>
# <span>02-26322693</span>
# </li>
# <li class="taps">
# <span class="tapR"></span> <span class="tapB">中文</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="09:40" data-movie_title="變身特務" data-movie_type="" data-news="news" id="72822591" name="schedule_list" type="radio" value="2020-01-25 09:40:00"/>
# <label class="" for="72822591">09:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="11:40" data-movie_title="變身特務" data-movie_type="" data-news="news" id="72822592" name="schedule_list" type="radio" value="2020-01-25 11:40:00"/>
# <label class="" for="72822592">11:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="13:40" data-movie_title="變身特務" data-movie_type="" data-news="news" id="72822593" name="schedule_list" type="radio" value="2020-01-25 13:40:00"/>
# <label class="" for="72822593">13:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="15:40" data-movie_title="變身特務" data-movie_type="" data-news="news" id="72822594" name="schedule_list" type="radio" value="2020-01-25 15:40:00"/>
# <label class="" for="72822594">15:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="17:40" data-movie_title="變身特務" data-movie_type="" data-news="news" id="72822595" name="schedule_list" type="radio" value="2020-01-25 17:40:00"/>
# <label class="" for="72822595">17:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="19:40" data-movie_title="變身特務" data-movie_type="" data-news="news" id="72822596" name="schedule_list" type="radio" value="2020-01-25 19:40:00"/>
# <label class="" for="72822596">19:40</label>
# </div>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="10:30" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822587" name="schedule_list" type="radio" value="2020-01-25 10:30:00"/>
# <label class="" for="72822587">10:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="14:30" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822588" name="schedule_list" type="radio" value="2020-01-25 14:30:00"/>
# <label class="" for="72822588">14:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="18:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822589" name="schedule_list" type="radio" value="2020-01-25 18:20:00"/>
# <label class="" for="72822589">18:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="21:40" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822590" name="schedule_list" type="radio" value="2020-01-25 21:40:00"/>
# <label class="" for="72822590">21:40</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="百老匯數位影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=52" data-theater_url="http://www.broadway-cineplex.com.tw/index.asp" id="theater_id_52">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=52">百老匯數位影城</a>
# <span>02-86636128</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="09:50" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822668" name="schedule_list" type="radio" value="2020-01-25 09:50:00"/>
# <label class="" for="72822668">09:50</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="11:40" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822669" name="schedule_list" type="radio" value="2020-01-25 11:40:00"/>
# <label class="" for="72822669">11:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="15:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822670" name="schedule_list" type="radio" value="2020-01-25 15:20:00"/>
# <label class="" for="72822670">15:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="20:50" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822671" name="schedule_list" type="radio" value="2020-01-25 20:50:00"/>
# <label class="" for="72822671">20:50</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="22:40" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822672" name="schedule_list" type="radio" value="2020-01-25 22:40:00"/>
# <label class="" for="72822672">22:40</label>
# </div>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> <span class="tapB">中文</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="10:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822677" name="schedule_list" type="radio" value="2020-01-25 10:20:00"/>
# <label class="" for="72822677">10:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="14:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822678" name="schedule_list" type="radio" value="2020-01-25 14:20:00"/>
# <label class="" for="72822678">14:20</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="東南亞秀泰影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=53" data-theater_url="http://www.showtimes.com.tw/" id="theater_id_53">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=53">東南亞秀泰影城</a>
# <span>02-23678999</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> <span class="tapB">中文</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="10:00" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822706" name="schedule_list" type="radio" value="2020-01-25 10:00:00"/>
# <label class="" for="72822706">10:00</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="14:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822707" name="schedule_list" type="radio" value="2020-01-25 14:20:00"/>
# <label class="" for="72822707">14:20</label>
# </div>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="12:10" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822699" name="schedule_list" type="radio" value="2020-01-25 12:10:00"/>
# <label class="" for="72822699">12:10</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="16:30" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822700" name="schedule_list" type="radio" value="2020-01-25 16:30:00"/>
# <label class="" for="72822700">16:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="18:40" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822701" name="schedule_list" type="radio" value="2020-01-25 18:40:00"/>
# <label class="" for="72822701">18:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="20:50" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72822702" name="schedule_list" type="radio" value="2020-01-25 20:50:00"/>
# <label class="" for="72822702">20:50</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="今日秀泰影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=112" data-theater_url="http://showtimes.pixnet.net/blog" id="theater_id_112">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=112">今日秀泰影城</a>
# <span>02-23751669</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="10:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72824636" name="schedule_list" type="radio" value="2020-01-25 10:20:00"/>
# <label class="" for="72824636">10:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="14:30" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72824637" name="schedule_list" type="radio" value="2020-01-25 14:30:00"/>
# <label class="" for="72824637">14:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="18:40" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72824638" name="schedule_list" type="radio" value="2020-01-25 18:40:00"/>
# <label class="" for="72824638">18:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="20:45" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72824639" name="schedule_list" type="radio" value="2020-01-25 20:45:00"/>
# <label class="" for="72824639">20:45</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="22:50" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72824640" name="schedule_list" type="radio" value="2020-01-25 22:50:00"/>
# <label class="" for="72824640">22:50</label>
# </div>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> <span class="tapB">中文</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="12:25" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72824651" name="schedule_list" type="radio" value="2020-01-25 12:25:00"/>
# <label class="" for="72824651">12:25</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="16:35" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72824652" name="schedule_list" type="radio" value="2020-01-25 16:35:00"/>
# <label class="" for="72824652">16:35</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="美麗新大直皇家影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=191" data-theater_url="https://www.miranewcinemas.com/" id="theater_id_191">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=191">美麗新大直皇家影城</a>
# <span>02-7718-8588</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="10:50" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72825486" name="schedule_list" type="radio" value="2020-01-25 10:50:00"/>
# <label class="" for="72825486">10:50</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="12:50" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72825487" name="schedule_list" type="radio" value="2020-01-25 12:50:00"/>
# <label class="" for="72825487">12:50</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="15:00" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72825488" name="schedule_list" type="radio" value="2020-01-25 15:00:00"/>
# <label class="" for="72825488">15:00</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="17:10" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72825489" name="schedule_list" type="radio" value="2020-01-25 17:10:00"/>
# <label class="" for="72825489">17:10</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="19:20" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72825490" name="schedule_list" type="radio" value="2020-01-25 19:20:00"/>
# <label class="" for="72825490">19:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="21:40" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72825491" name="schedule_list" type="radio" value="2020-01-25 21:40:00"/>
# <label class="" for="72825491">21:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="23:50" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72825492" name="schedule_list" type="radio" value="2020-01-25 23:50:00"/>
# <label class="" for="72825492">23:50</label>
# </div>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> <span class="tapB">中文</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="11:40" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72825493" name="schedule_list" type="radio" value="2020-01-25 11:40:00"/>
# <label class="" for="72825493">11:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="16:10" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72825494" name="schedule_list" type="radio" value="2020-01-25 16:10:00"/>
# <label class="" for="72825494">16:10</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '變身特務']" data-movie_date="01.25" data-movie_time="17:30" data-movie_title="變身特務" data-movie_type="數位" data-news="news" id="72825495" name="schedule_list" type="radio" value="2020-01-25 17:30:00"/>
# <label class="" for="72825495">17:30</label>
# </div>
# </li>
# </ul>]

# %%
for ht in html:
    movie_type = ht.find("span",attrs={'tapR'}).text
    theater_name = ht.find("a").text
    time = ht.find(class_='value')

        
    print("電影類型:",movie_type,'\n',"電影院：",theater_name,'\n',type(time),time)

'''

  試著從上一步驟回傳的電影院資料中，擷取電影院名稱、影片放映類型以及時間表
  
  Your code here.

'''
# Out:
# 電影類型: 數位
#  電影院： 國賓影城(台北長春廣場)
#  <class 'NoneType'> None
# 電影類型: 數位
#  電影院： 欣欣秀泰影城
#  <class 'NoneType'> None
# 電影類型: 數位
#  電影院： 華威天母影城
#  <class 'NoneType'> None
# 電影類型: 數位
#  電影院： 國賓大戲院(西門)
#  <class 'NoneType'> None
# 電影類型: 數位
#  電影院： 國賓影城(微風廣場)
#  <class 'NoneType'> None
# 電影類型:
#  電影院： 哈拉影城
#  <class 'NoneType'> None
# 電影類型: 數位
#  電影院： 百老匯數位影城
#  <class 'NoneType'> None
# 電影類型: 數位
#  電影院： 東南亞秀泰影城
#  <class 'NoneType'> None
# 電影類型: 數位
#  電影院： 今日秀泰影城
#  <class 'NoneType'> None
# 電影類型: 數位
#  電影院： 美麗新大直皇家影城
#  <class 'NoneType'> None
# '\n\n  試著從上一步驟回傳的電影院資料中，擷取電影院名稱、影片放映類型以及時間表\n  \n  Your code here.\n\n'
